# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/MyDrive/lip_sync

# %%
cd drive/MyDrive/lip_sync/
# Out:
# /content/drive/MyDrive/lip_sync

# %%
# !pip install gfpgan
# !pip install basicsr

# %%
# !apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg

# %%
# !pip install PyAudio

# %%
# !pip install -r requirements_stt.txt

# %%
# !python inference.py --checkpoint_path checkpoints/wav2lip_1.pth --face my_test/me.jpg --audio my_test/voice.mp3

# %%
# !npm install localtunnel

# %%
# !streamlit run STT.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.203.163.115
# npx: installed 22 in 4.015s
# your url is: https://afraid-candles-repeat.loca.lt
